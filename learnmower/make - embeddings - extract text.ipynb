# %%
import numpy as np 
import pandas as pd
import os
import gc

# regex libraries
import re
import regex
import string

# tokenizer library
import codecs
from keras.preprocessing.text import Tokenizer
# Out:
# C:\Users\tyoko\Anaconda3\envs\tensorflow\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# standard directories
data_dir = '../input/kaggle_data'
plain_text_dir = '../input/plain_text'
fasttext_dir = '../fasttext'

# %% [markdown]
# ### extract text

# %%
train = pd.read_csv(f'{data_dir}/train.csv', usecols=['title','description'])
train_input = train['title'].str.cat([
    train['description']
], sep=' ',na_rep='').astype(str).fillna('missing')

del train
gc.collect()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-69053f629039> in <module>()
# ----> 1 train = pd.read_csv(f'{data_dir}/train.csv', usecols=['title','description'])
#       2 train_input = train['title'].str.cat([
#       3     train['description']
#       4 ], sep=' ',na_rep='').astype(str).fillna('missing')
#       5
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     707                     skip_blank_lines=skip_blank_lines)
#     708
# --> 709         return _read(filepath_or_buffer, kwds)
#     710
#     711     parser_f.__name__ = name
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     453
#     454     try:
# --> 455         data = parser.read(nrows)
#     456     finally:
#     457         parser.close()
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1067                 raise ValueError('skipfooter not supported for iteration')
#    1068
# -> 1069         ret = self._engine.read(nrows)
#    1070
#    1071         if self.options.get('as_recarray'):
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1837     def read(self, nrows=None):
#    1838         try:
# -> 1839             data = self._reader.read(nrows)
#    1840         except StopIteration:
#    1841             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\dtypes\common.py in is_integer_dtype(arr_or_dtype)
#     775
#     776
# --> 777 def is_integer_dtype(arr_or_dtype):
#     778     """
#     779     Check whether the provided array or dtype is of an integer dtype.
#
# KeyboardInterrupt:

# %%
train_active = pd.read_csv(f'{data_dir}/train_active.csv', usecols=['title','description'])
train_active_input = train_active['title'].str.cat([
    train_active['description']
], sep=' ',na_rep='').astype(str).fillna('missing')

del train_active
gc.collect()
# Out:
# 7

# %%
test = pd.read_csv(f'{data_dir}/test.csv', usecols=['title','description'])
test_input = test['title'].str.cat([
    test['description']
], sep=' ',na_rep='').astype(str).fillna('missing')

del test
gc.collect()
# Out:
# 7

# %%
test_active = pd.read_csv(f'{data_dir}/test_active.csv', usecols=['title','description'])
test_active_input = test_active['title'].str.cat([
    test_active['description']
], sep=' ', na_rep='').astype(str).fillna('missing')

del test_active
gc.collect()
# Out:
# 7

# %%
def clean_text(text):
    text = bytes(text, encoding="utf-8")
    text = text.lower()
    text = re.sub(b'(?<! )(?=[.,!?()])|(?<=[.,!?()])(?! )', b' ', text)
    text = re.sub(b'\s+(?=\d)|(?<=\d)\s+', b' ', text)
    text = text.replace(b"\b", b" ")
    text = text.replace(b"\r", b" ")
    text = regex.sub(b"\s+", b" ", text)
    text = str(text, 'utf-8')
    text = re.sub(r"\W+", " ", text.lower())
    return text

# %%
# create full corpus
text_input = train_input + train_active_input + test_input + test_active_input

# %%
text_input = list(pd.concat([train_input, train_active_input, test_input, test_active_input], axis=0).values)
text_input
# Out:
# ['Кокоби(кокон для сна) Кокон для сна малыша,пользовались меньше месяца.цвет серый',
#  'Стойка для Одежды Стойка для одежды, под вешалки. С бутика.',
#  'Philips bluray В хорошем состоянии, домашний кинотеатр с blu ray, USB. Если настроить, то работает смарт тв /\nТорг',
#  'Автокресло Продам кресло от0-25кг',
#  'ВАЗ 2110, 2003 Все вопросы по телефону.',
#  'Авто люлька В хорошем состоянии',
#  'Водонагреватель 100 литров нержавейка плоский Электро водонагреватель накопительный на 100 литров Термекс ID 100V, плоский, внутренний бак из нержавейки, 2 кВт, б/у 2 недели, на гарантии.',
#  'Бойфренды colins Бойфренды в хорошем состоянии.',
#  'Платье 54 раз мер очень удобное',
#  'Полу ботиночки замш натур.Бамбини По стельке 15.5см мерить приокский район. Цвет темнее чем на фото',
#  '1-к квартира, 25 м², 2/2 эт. Сдается однокомнатная мебелированная квартира квартира. Ежемесячная плата 18 тыс.р. + свет.',
#  'Джинсы ',
#  'Атласы и Контурныя карты за 8 класс Атлас история нового времени,19 век./\nКонтурные карты история нового времени,19 век./\nКонтурные карты по Географии./\nЦена указана за один товар.',
#  'Монитор acer 18.5 Продам манитор 18.5 v193HQV. В хорошем состоянии',
#  'Продаются щенки немецкой овчарки родились 1 февраля,три кобеля и сучка.',
#  'Платье женское новое Одето 1 раз на пару часов. Длина 79. Можно кормящим грудью мамочкам. Очень удобно. Платье с пришивным пояском и карманами. Декорировано змейкой на груди. На вид-совершенно новое платье. Цвет темно синий.',
#  'Chevrolet Lanos, 2008 Кондиционер, гидроусилитель руля, электрические стеклоподъемники. Мотор как  на Opel. Дополнительно установлена сигнализация./\nПТС оригинал, 3 хозяина, машина местная./\nМашина полностью на ходу, технически все исправно. /\nДокументы в порядке. /\nКузов не гнилой и не ржавый, машина не билась, но есть недочеты видные на фото. /\nЦена адекватная, торг минимальный./\nОсмотр в Краснодаре, в районе нового стадиона по ул. Восточно- Кругликовской.',
#  'Объемная цифра 2 Размеры 75*53*15. Основа-картон, декор-гофрированная бумага.',
#  'Куртка весенняя(осенняя) Куртка новая, очень удобная, ценник был утерян при переезде, возможен торг!',
#  'Сниму коттедж Семейная пара из двух человек снимет коттедж с дизайнерским ремонтом, со стильной мебелью и бытовой техникой. Гараж на 2 машины, 2 санузла. Огороженная территория, сигнализация.  Рассмотрим варианты коттеджей, которые выставлены на продажу. Ежемесячная оплата до 100 тыс.руб. в месяц.  Агентства просьба не беспокоить.',
#  '2-к квартира, 44 м², 5/5 эт. Дом находиться внутри квартала./\nПластиковые окна во всей квартире, балкон застеклен железом, обшит деревом, в комнате натяжной потолок, новый линолиум,/\nванна и туалет- стеновые панели.Квартира подходит под ипотеку, 1 собственник, ЧП, небольшой торг возможен.',
#  'Шапка норковая Продам шапку, норка, цвет коричневый, в отличном состоянии, б/у несколько раз. Цена 2 600 рублей. Торг уместен.',
#  'Ford Focus, 2005 Полная комплектация. ГУР. 4 эсп.  Подогрев сидений зеркал заднего стекла. Эл.зеркала.  Климат. АБС.  Птф. Кожаный салон эл.лифт сидений.  Торг.',
#  'Туфли moschino Очень красивые стильные туфельки, состояние отличное',
#  'Таблетки бравекто Таблетки "Бравекто" от блох и клещей по ценам: /\n- для собак от 2 до 4,5 кг 1050 рублей /\n- для собак от 4,5до 10 кг 1100 рублей /\n- для собак от 10 до 20 кг 1150 рублей /\n- для собак от 20 до 40 кг 1250 рублей /\n- для собак от 40 до 56 кг 1400 рублей/\nДействие таблектки 3 месяца.',
#  'Пинки Пай My Little Pony Пинки Пай ждёт любящую хозяйку./\nВ комплекте с ней идут: бутылочка, небольшая сумочка, бусы. Поняшка не сломана, разговаривает, кушает, может сидеть. Продаётся, потому что ребёнок вырос и не хочет с ней играть.',
#  'Ламбрикен Продам ламбрикен в хорошем состоянии,длина 2,20.',
#  'Ботинки Ботинки б/у в хорошем состоянии. Размер 37',
#  'Продаю новое платье Новое, очень нарядное платье, Рост 170 см, размер 46.',
#  'Песочник Crockid Состояние хорошее, носили мало.',
#  'Фасадные панели Уникальные свойства фасадных панелей FineBer позволяют им быть на пике привлекательности среди существующих облицовочных материалов. Вместе с практичностью, свойственной искусственным покрытиям, панели FineBer обладают важным свойством – они естественно передают поверхность природных материалов. Все больше владельцев загородных домов отдают предпочтение фасадным панелям, поскольку это наиболее выигрышный и экономичный способ придать жилью свежий и естественный вид. Изготовленные методом литья, панели прекрасно подходят для сплошной облицовки фасада и отделки цоколя.',
#  'Бычки продаю бычков на откорм веса от 150 до 220',
#  'Кулер для компьютера cooler master Чтобы посмотреть весь ассортимент нашего магазина перейдите по ссылке в блоке справа ⇒⇒⇒⇒⇒⇒⇒⇒⇒⇒⇒⇒⇒⇒/\nНАЛИЧИЕ ТОВАРА УТОЧНЯЙТЕ ПО КОТАКТНОМУ ТЕЛЕФОНУ./\n Продам Кулер для компьютера COOLER MASTER/\n /\nВ НАШЕМ МАГАЗИНЕ НА ТЕХНИКУ ДАЕТСЯ ГАРАНТИЯ!!!!!!/\n========================================/\n Находимся по адресу: г. Пермь, ул. Карпинского. 109. (вход на углу дома с правого торца), работаем ежедневно с 10.00 до 20.00 без обеда./\n ========================================/\n Комиссионный магазин "SecondLifeElectric" продаёт, покупает, обменивает или принимает на комиссию и под денежный залог, как БУ, так и новую бытовую технику, электронику, а так же электро - бензо инструмент./\n/\n Надёжная техника по доступной цене./\n Обновление ассортимента происходит ежедневно./\n ========================================/\n Покупая у нас, Вы получаете:/\n Гарантию!/\n Технику, которая обязательно проходит предпродажную подготовку!/\n Консультацию специалиста (в нашей компании работают 3 мастера по разным направлениям)!/\n Скидка на технику до 20 %!!!/\n Поддержку и помощь в ремонте после окончания\xa0гарантийного срока./\n Бесплатный вывоз старой крупногабаритной бытовой техники (не старше 10 лет)./\n Так же в наличии есть новая техника с ГАРАНТИЕЙ!/\n ========================================/\n Наша продукция имеет отличное техническое и внешнее состояние, обязательно проходит диагностику, качественный ремонт, проверку, мойку и чистку, только после данной процедуры техника попадает на витрину с минимальной гарантией 14 дней!!!/\n ========================================/\n Наша компания предоставляет услуги по профессиональному ремонту и обслуживанию бытовой техники и электроники, а так же электроинструмента.\xa0/\n ========================================/\nПрофессиональный ремонт и обслуживание стиральных машин./\n Наш мастер проконсультирует вас и сделает все возможное, чтобы ваша стиральная машина снова радовала вас!/\nРемонт стиральных машин осуществляется на дому, либо в мастерской (выезд и диагностика бесплатно, даже в случае отказа от ремонта). Причину поломки и примерную стоимость скажут по телефону. На все работы с заменой деталей дается гарантия./\n ========================================/\nПрофессиональный ремонт компьютеров и ноутбуков по самым низким ценам в городе, с ГАРАНТИЕЙ на работы и материалы./\n Обращаясь к нам вы получаете:/\n Бесплатную консультацию по телефону/\n Бесплатный (срочный) выезд на дом (в офис) в черте города/\n Стоимость работ оговаривается по телефону, либо перед выполнением работ/\n Качественно выполненную работу и гарантию/\n ***Бесплатную установку антивирусной программы***/\n/\nСо всем ассортиментом вы можете ознакомится у нас в Авито- Магазине/\n Смотри ниже! Тут весь наш товар!/\n -------------------⇘⇘⇘⇓⇓⇓⇓⇓⇓⇓⇓⇓⇓⇓⇓⇓⇙⇙⇙------',
#  'Комната 8.2 м² в 5-к, 3/5 эт. Продаю тёплую комнату с отличным новым ремонтом в 5-комнатной квартире./\nКомната в отличном состоянии! Ремонт делали недавно:/\n- комнате пластиковое окно на солнечную сторону, /\n- новые пластиковые трубы и батарея,/\n- хорошие современные обои,/\n- натяжной потолок,/\n- на полу линолеум,/\n- хорошая входная дверь./\nВ комнате остается вся мебель: раскладной диван, новый шкаф, холодильник, телевизор, микроволновая печь, стол-трансформер./\nНа общей кухне свой стол, плита. Санузел раздельный, душевая в кафеле, всё в чистом виде. Хорошие соседи, не шумные. /\nВсе документы готовы к продаже, один взрослый собственник. Возможна ипотека(помощь в оформлении)./\nПоказы в любое удобное время. Звоните!',
#  'Audi 80, 1986 Отличный надёжный немец, на очень бодром ходу! Новые колёса с новой резиной. Новые сиденья, кожаные чехлы, гидроусилитель руля, люк, Кузов оцинкованный не гнилой! Дно целое! Пороги в идеале. Любые запчасти без проблем и дешевле чем на отечественные авто. Остальные вопросы по телефону',
#  'Коляска 2016 года Модульная детская коляска на низко профильной резине. Которая вас не подведёт ни проколом, ни спусканием. Модуль для деток постарше или как его называют летний СОВЕРШЕННО НОВЫЙ. Вся комплектация. Документы и чек в наличии, в ПОДАРОК отдам вещи которые на фотографии.',
#  'Берцы bates Gore-Tex 7R БЕРЦЫ BATES  Gore-Tex®, новые. Может надетые пару раз,не больше. Длина стельки - 26,5 см.',
#  'Медаль ВАЗ. В честь пуска завода Настольная памятная медаль Волжский автомобильный завод им. 50 летия СССР. В честь пуска завода. 1967-1973. Медаль в хорошем состоянии. Выпущена в 1973 г. с хорошим художественным уровнем. Изготовлена из медно-никелевого сплава (вероятно, мельхиор). Диаметр 65 мм, толщина 3 мм (по гурту - 4 мм), гурт гладкий.',
#  'Склад 70 м² Продается склад ГСМ, по адресу п. Истровка, Калининградской обл, Гвардейского района, площадью 70 кв.м, с прилегающей територией 16 сот.',
#  'Свадебные туфли Продам новые туфли фирмы Louisa Peeress 37р',
#  'Брюки джинсовые Длина по боковому шву=88см. Обхват талии= 66см(регулируется). Обхват бедер=86см. Находимся на северо-востоке.',
#  'Летний комбинезончик. новый Продам. Новый. Нейтральный цвет. Подойдёт как для девочки, так и для мальчика. Написано 12 мес. Маломерит. Мы быстро выросли и не успели одеть.',
#  'Шлем киват kivat Шлем киват после одного ребёнка, дочка родилась зимой мы носили с рождения и ещё на следующей год носили. Очень тёплый, и удобный. Размер 0. Состояние хорошее, но видно что активно носили)) все мои дети ходят в шлемах kivat, хотя мной было перепробовано множество других шлемов и шапок, если думаете что одевать малышке которая рождается осенью или зимой, смело берите такой шлем, никакой дополнительной поддевы и чепчиков одевать не надо будет и нет завязок, которые так сильно нервируют малышей))',
#  'Футболка Adidas (хорошее состояние) В хорошем состоянии футболка Adidas, оригинал, про-во Тайланд, чистая, немного б\\у, подойдет на размер 44-46',
#  '1-к квартира, 44 м², 13/16 эт. ПВХ, отличное состояние. Парковочное место. Вид на Енисей. Торг./\n /\nag25/\n /\nid95299',
#  'Полка хром, двухярусная ',
#  'Одеяло атласное двуспальное, теплое Продам 2спальное одеяло: ватное, стеганое, ткань атлас, красного цвета. Чистое. Теплое. Толщина в среднем больше 4 см. Вечное) Просто подарили новое)/\nПарк Победы. Уважаемый покупатель, возьмите с собой большой пакет, у меня пакетов таких размеров не осталось.',
#  'Детский развивающий коврик ',
#  'Коляска б/у трость Продаю коляску-трость б/у в хорошем состоянии. Спинка регулируется, занимает мало места, удобно переносить.',
#  'Набор для маникюра Продам набор всё для маникюра /\nИспользовала несколько раз,что то вообще новое. 21 цвет лака,набор дотсов,краски для дизайна и многое другое....всё что на фото',
#  'Сапожки демисезонные next.,5 Сапожки демисезонные NEXT. /\nРазмер 20,5 (4 Великобритания), стелька 14 см./\n/\nЦена 700 рублей, новые./\nЩербинки',
#  '2-к квартира, 42.5 м², 6/6 эт. 2-комн. квартира (студия плюс спальня) под ключ (мансарда), 42,5 кв.м., теплые полы, высокие потолки, установлена сантехника, кондиционер, кухонный гарнитур: встроенная варочная поверхность, духовка, оборудованная детская площадка, 100м до остановки, вид на море, детская площадка, поликлиника школа детский сад не далеко. Квартира более 4 лет в собственности. СОБСТВЕННИК!',
#  'Все юбки и брюки за 300 ',
#  'Аквариум ювель Отличный аквариум немецкого качества ЮВЕЛЬ, отдам все вместе!с тумбой рыбками 2 фильтра 30-40 рыб, камни, растения очень дорогие. Новый',
#  'Смартфон Explay Blaze (белый) продаю-Смартфон Explay Blaze (белый)Диагональ (дюйм): 5.5/\nРазрешение (пикс): 960x540/\nФотокамера (Мп): 8/\nПроцессор: MediaTek MT6582M/\nКоличество ядер: 4/\nОперативная память (Мб): 1024-полный комплект-состояние нового.',
#  'Сниму комнату Девушка без вредных привычек ... Снимет  квартиру в Калининском районе ... С хорошим ремонтом....Агенством не беспокоить!',
#  'Матрас Продам матрас пружинный б/у размер 1200-2000 в хорошем состоянии.',
#  'Сандали Indigo, размер 19, состояние новых ',
#  'Золото 585(лом) 1550р. За 1 грамм!',
#  'Туфли для мальчика Продам туфли для мальчика фирмы Котофей, размер 35, в отличном состоянии. Звонки на номер после 17.00 ч.',
#  'Быстровозводимые каркасные строения В строительстве мы используем и развиваем следующие технологии:/\nстроительство каркасного дома/\nстроительство брусовых домов/\nМы предлагаем:/\nСтроительство Домов Бань Беседок и Разнообразные Хоз постройки/\nнулевой цикл/\nустройство фундамента/\nкровельные, фасадные работы,/\nДля комфорта наших заказчиков мы производим комплектацию объекта материалами . Причем наши цены на материалы и системы ниже среднегородских, т.к. с поставщиками и производителями у компании «ЭкоСадСтрой» дилерские контракты./\nВсе задачи выполняются только квалифицированными специалистами. /\nАкция !!! Построй дом на своем участке 6 на 6 с верандой 1.5 на 3 всего за 499тр ПОД КЛЮЧ!!!!! /\nПенсионерам скидки, при заказе дома на последующие заказы скидка от 10%!!! звоните спрашивайте ответим на все интересующие вас вопросы',
#  'Бегающий енот Новый в упаковке, не использовали.',
#  'Сандалики текстильные Сандалики в хорошем состоянии, легкие, удобные',
#  'Комбинезон ветровочный Reima Для межсезонья. Не промокает, не продувается. Редкий цвет.',
#  "Продам куртку Marc 'O Polo В отличном состоянии",
#  'Монтаж дверей, проемов, откосов, арок Установка межкомнатных дверей 1200-1600руб, монтаж входной двери 1500-2500руб, облагораживание проема 1200, откосы на входную дверь 1000 руб. Установка арки 1500руб. Цена зависит от дополнительных работ, если потребуется (расширение/заужение проема, фрамуга сверху, обрезка наличника и прочее) Выезд в любой район. Новоильинским небольшая скидка',
#  'Наращивание ногтей, коррекция Мастер с 9 летним стажем ждет Вас, красавицы! Наращивание, коррекция, шеллак! Неограниченное разнообразие цветов, дизайнов (Вся палитра цветов, сахар, мармелад, камифубуки, кристаллы, кошачий глаз и многое другое) Спешите записаться! Качество гарантирую! Жду всех на Лавочкина,3./\nНаращивание - 700р/\nКоррекция - 600р/\nШеллак - 500р/\nПишите в ЛК я напишу свой номер, на этот звонить в крайнем случае, спросить Олесю! До встречи)',
#  'Сапоги фирмы "Carlo Pazolini" бежевые Продам сапоги фирмы "Carlo Pazolini" бежевые, сезон осень/весна./\n/\nТ.к. данная фирма большемерит, размер на подошве 37, по факту 38./\nСапожки не на худенькое голенище!) На среднее!/\n/\nНовые, ни разу не одела. Приклеены анти скользящие стельки.',
#  'Продаются поросята Продаются поросята от 1,5 мес.',
#  '"Индийский бегун" большого размера Яйцо на инкубацию уток породы "Индийский бегунок", утки большого размера. В нашем хозяйстве есть "Индийские бегуны" стандартного и большого размера.',
#  'Кроссовки детские р.34 Dinosoles. Мигающие красными огоньками. Хорошее состояние. Замша.',
#  'Женская дубленка Продам дубленку 42-44 размера /\nДублёнке 4 года, очень теплая /\nмех желтоват, но в хорошем состоянии',
#  'Ортопедическая обувь. Натуральная Ортопедическая, натуральная Обувь. Покупала в тандеме за 4800',
#  'Костюм для игры черепашка ниндзя Рафаэль Костюм для игры черепашка ниндзя Раф.Отличного качеста из хорошей пластмассы.Без запаха.По размеру для ребенка не меньше 5 лет. А так регулируется практически до взрослого размера.На фото линейка 20 см .В набор входит ПАНЦИРЬ регулируется ремешками через грудь и подмышки,имеет держатели для КИНЖАЛЫ САЙ-2шт. кинжалов, МАСКА черепашки регулируется по головке ребенка резинкой с липучкой ,части прилегающте к лицу не пластмассовые,а из мягкой резины,как на маске для ныряния.И НАКЛАДКИ на колени и локти-4 шт.Из мягкого материала с липучками.Состояние отличное.Покупали в "Детском мире"за 4000р. Забирать на Родионова.Если без примерки,то как варианты Водная Академия и пл.Комсомольская',
#  'Муж на час или дольше предоставляю все виды работ по дому,работаю в любое время суток,цена договорная',
#  'Сумка синяя, не ношена ',
#  'Кроссовки роликовые смотреть на Федюнинского размер 40 маломерят',
#  'В подарок для месячного малыша Прекрасно подойдет в качестве подарка для новорожденного мальчика. /\nБархатный, темно-синий цвет./\nРазмер 50-56  (0-2 мес). /\nРаспродажа товара по ценам производителя. /\nПроизводство: Польша',
#  '1-к квартира, 42 м², 7/14 эт. ДОМ СДАН,КЛЮЧИ!!!/\nРасположение «Максима» — самое сердце «Металлурга». Этот тихий зелёный уголок часто предпочитают другим спальным районам города./\nВ районе уже есть все необходимое для жизни. Рядом лесопарковая зона — всей семьей можно прогуляться в парке Кирова, посетить зоопарк./\nОколо дома есть несколько остановок, а для автомобиля предусмотрена вместительная парковка.',
#  'Хоккейная форма комплект 50-52 р.р Продается хоккейная форма полный комплект. Все в хорошем состоянии. В подарок чехлы на коньки.',
#  'Босоножки и туфельки Продам босоножки на фото 2 размер 22, цена 200. Босоножки с фото 3 носили в саду. Дефект на фото. Ещё послужат. За 100. Туфельки одеты раза 3. Состояние очень хорошее. 300.',
#  'Комбинезон Продам. Есть дефект, отвалилась собачка, нужно новую поставить.',
#  'Рупор Продам громкоговоритель новый. Уличные рекламщики, он вам просто необходим!!!',
#  'Стиральная машина LG,5 кг., гарантия Продаю стиральную машину в отличном рабочем состоянии. Обладает всеми необходимыми функциями для безупречной стирки. Станет идеальной помощницей в вашем доме. Загрузка фронтальная на 5 кг. По вашей просьбе помогу с доставкой, подключением, подъемом на этаж. Гарантия 6 месяцев. Также имеется ряд стиральных машин, холодильников с гарантией. Возможен взаимозачет старой техникой.',
#  'Сапожки весенние Продам ботинки иск. замша, в отличном состоянии (одевались 2 раза), размер-35, каблук-скала',
#  'Джинсы Бержка Фирменные джинсы, бу несколько раз',
#  'Джинсы Джинсы весна- осень, лето в прохладную погоду, в отличном состоянии.',
#  'Модуль оперативной памяти Продаю оперативную память kingmax DDR-400, 512 MB- 250 руб, hynix DDR333, 512 MB- 250 руб., hynix DDR333, 256 MB- 150 руб., DIGMA DDR333, 256 MB- 150 руб.',
#  'Красивое пальто для девочки Продам детское пальто на межсезонье. Цвет серо-розовый. Качество отличное!!! Покупали в отделе "НАСЛЕДНИК"',
#  'Отвертки для ремонта ноутбуков Отвёртки для ремонта ноутбуков/\nНовые',
#  'Sony PlayStation One(2002) Состояние: Отличное для возраста приставки./\nИгры отдам вместе с приставкой./\nОстальное по телефону, либо при осмотре.',
#  'Участок 7 сот. (промназначения) Продам участок под строительство торгового павильона по ул.Коммунальной.',
#  'Яйцо куриное Яйцо домашние всегда свежее.',
#  'Мужской свитер В хорошем состоянии,могу выслать почтой',
#  'Новые свадебные платья Закрыла салон в прошлом году,  платья новые, примерка по записи за 1 день минимум,только если вам понравилось платье с фотографии!!!  платьев осталось не много, размер в наличии тот,что подписан. Платья в идеальном состоянии, фирменные, отдаю по себестоимости! БЕЗ ТОРГА!/\nПлатье номер 1 В Наличии цвет Айвори классическое бальное платье от TM ARMONIA/\nПлатье номер 2 БЕЛОЕ, ТМ Юнона карсет расшит бисером, смотрится очень нежно, платье в жизни пышное',
#  'Продам детскую стенку с кроватью Продам детскую мебель с матрацем, шкаф плательный вместительный, полочки под книжки есть',
#  'Сапожки весна-осень Продам сапожки весна-осень в отличном состоянии. Надевали пару раз.',
#  'Телевизор цветной ',
#  'Audi A1, 2013 Продам свою любимую машину!! Быстрая, яркая, стильная и юркая! Обслуживание только у официального дилера! Прекрасное состояние! До полной комплектации не хватает только мультируля! Климат, Ауди концерт, комплектация амбишн, все включено!) уже по ней скучаю ;(',
#  'Отличные ботиночки! Продам ботиночки натуральная кожа,в отличном состоянии ,21 размер.',
#  'Мобильный телефон Alcatel POP C7 7041D арт. 9718 Состояние: Отличное/\n /\nКомплект:\xa0Нет/\n /\n______________________________________________________/\n /\nAndroid 4.2\xa0/\nподдержка двух SIM-карт\xa0/\nэкран 5", разрешение 854x480\xa0/\nкамера 5 МП, автофокус\xa0/\nпамять 4 Гб, слот для карты памяти\xa0/\n3G, Wi-Fi, Bluetooth, GPS\xa0/\nобъем оперативной памяти 512 Мб\xa0/\nаккумулятор 2000 мА⋅ч/\n /\n______________________________________________________/\n /\nУстройство прошло проверку специалистами и полностью исправно!/\n /\nВозможна доставка по РФ. Любым удобным вам способом./\n /\nО МАГАЗИНЕ/\n /\nВремя работы: КРУГЛОСУТОЧНО./\n /\nАдрес: г. Оренбург ул. Химическая 2 Остановка: РТИ/\n /\n- ТАК ЖЕ КУПИМ ВАШЕ ЦЕННОЕ ИМУЩЕСТВО -',
#  'Кеды DC shoes trase tx Кеды новые , продаю , потому что не подошли по размеру . Не разу не одевал их .',
#  'Продаю котёл Fondital Victoria 24 fi Продаю настенный котёл. В эксплуатации не был. Торг.',
#  '1-к квартира, 24 м², 2/8 эт. Жилой комплекс в статусе "квартира" с закрытой для общего доступа и охраняемой территорией, вход жильцов и гостей в дом на которую организован через единую рецепцию. Видео наблюдение, бассейн, детские площадки, придомовая парковка. На первых этажах запроектированы объекты инфраструктуры: ресторан, салон красоты, магазины, кафе, спорт комплекс (все коммерческие помещения имеют отдельный вход). Подробно о комплексе по телефону!',
#  'Весенние сапожки шоколадного цвета Новые весенние сапожки шоколадного цвета за небольшую стоимость)',
#  'Кенгуру! сумка кенгуру для переноски ребёнка ,на замке!',
#  'Дача 20 м² на участке 10 сот. Продаю дачный участок на берегу Верхнеуфалейского пруда. Домик с пристроем для хранения инвентаря и погребом для хранения урожая. Место для стоянки авто. Баня из бруса (2 отделения). 2 металлические теплицы покрытые стеклом. Большой разработанный участок для выращивания овощей и ягод. Плодово ягодные кусты и деревья (яблоня, груша, вишня, облепиха, смородина, крыжовник и т.п.). Прекрасное место для летнего отдыха и рыбалки. Документы на собственность дома и земли отдельные и в наличии.',
#  'ВАЗ 2107, 2001 Ваз 2107 в отличном состоянии, полностью на ходу, коробка 5ст, Центральный замок, музыка, хорошая летняя резина. торг уместен. /\n/\nВаз 2109 1990г. в. В отличном состоянии на полном ходу, салон ухоженный, передние сиденья на пульте управления. Центральный замок, музыка, торг уместен. 52 000руб.',
#  'Детские ботиночки Продаются недорого новые детские ботиночки 21 р. Покупались на распродаже в детском мире летом. К сезону стали малы.',
#  'Комбинезон детский ',
#  'Ищем Кота Вислоухого для вязки Кошечка. Первая вязка. Без документов ./\nТолько шотландца вислоухого .',
#  'Куртка ',
#  'Билеты на сборную России Продаю два билета.цена 2000 торг',
#  'Манипулятор Предлагаются услуги манипулятора по шахтам и Ростовской обл. Цена договорная',
#  'Продам плойку Продам многофункцуальную плойка,утюг для выпрямления волос,и еще куча разных насадок',
#  'Свитер на рост 98-104 см Свитер б/у в идеальном состоянии',
#  'Весенний костюм lassie Не промокает, не продувается, легко стирается, быстро сохнет, покупали в Детском Мире. Длина по внутреннему шву 34 см, длина рукава 43 см, штаны внизу на утяжке',
#  'ЖК- монитор Новый. Широкоформатный (16:9) мультисистемный цветной переносной ЖК- монитор. С документами./\nЗабирать в сипайлово',
#  'Е.Вильмонт роман и повесть про любовь Продам книгу Е.Вильмонт . В книге роман "Плевать на все с высокой секвойи" и повесть "Умер-шмумер". Это вариации на вечную тему - ЛЮБВИ. Кто знает этого автора, тот любит её произведения. Приятно взять в дорогу. Твердый переплет.',
#  'Видеокамера sony handycam Видеокамера SONY DSR-DVD405E/\n3.0 MEGA PIXELS/\nОбъектив Carl Zeiss Vario-Sonnar T/\nЗвук DOLBY DIGITAL 5.1/\nDIGITAL ZOOM 120/\nЗапись сразу на диск/\nВозможность делать фото/\nПолный комплект/\nЧехол',
#  'Маранта Маранта триколор',
#  '1-к квартира, 19 м², 1/2 эт. Продаю комнату-гостинку, Лукина,1, 1/2кирп, 19м, в отличном состоянии. Чистая продажа, срочно, возможна ипотека. 1190т.р',
#  'Фурнитура Фурнитура для одежды.',
#  'Бриджи В новом состоянии.  На возраст до 3 лет',
#  'Ботильоны Продам ботильоны весна -осень. Размер 38. Цена 1000 рублей. /\n/\nПишите и звоните на указанный номер телефона. Сообщения на Авито не открываются.',
#  'Комната 21 м² в 1-к, 4/5 эт. Ищу соседку в однокомнатную квартиру',
#  'Костюм вязаный Практически новый.',
#  'Серьги енот Серьги из полимера. 250 р. Товар не был в употреблении – НОВЫЙ. Посмотреть, купить можно, встретившись со мной в любой день после 14:00, в центре Саратова. В другой город высылаю почтой после 100% предоплаты + доставка. Пишите смс. ЕСЛИ ОБЪЯВЛЕНИЕ ВИСИТ, ЗНАЧИТ, ВЕЩЬ НЕ ПРОДАНА.',
#  'Куплю 2-к квартиру Срочно куплю 2 комнатную или 3-х млг квартиру в р-не БХЗ или Эйдемана (дома ближе к 21школе).Кроме 1 этажа.',
#  'Сниму комнату Не дорого.условия можно по смс или позвоните. Прошу агентство не беспокоить. Денег нет портить лишнее.',
#  'Мембранная куртка Продам мембранную куртку, носили очень аккуратно. Размер 92.Водонепромокаемая и ветронепродуваемая. В магазине стоит 2700р.Торг.',
#  'Коттедж 103 м² на участке 9 сот. Каркасный 2-х этажный дом 7,5 х 7,5,  обшит сайдинг/черепица,./\n Два балкона, окна, двери металлопластик + металлические входные. Без чистовой отделки. /\n   Возможна отделка под Заказчика до "под ключ". Доп. винтовой фундамент под баню 3х6м/\nВодовод на участке, эл/щит на столбе.',
#  'Детская коляска Продам коляску.Состояние хорошее.Переносной конверт с твердым, ровным дном,перекидная ручка,регулируемая спинка,корзина для покупок.',
#  'Классика Массив дуба Германия Продам стенку , можно разделить на три отдельных блока. Классика. Массив дуба. Германия . длинна 367 см, высота -210. В отделах где стеклянные двери - имеется деликатная подвеска. Смотрится богато. Качество - на сотни лет.',
#  'Магнитола В рабочем состоянии',
#  'ГАЗ ГАЗель, 2010 Газель в отличном состоянии. Двигатель от Уаза, был сделан капитальный ремонт двигателя и коробки, новый стартер, генератор, радиатор (трехрядный) Новая резина по кругу (бескамерная)',
#  '1-к квартира, 54 м², 5/9 эт. Продам или обменяю',
#  'Новые леггинцы Livia Co Польша Новые леггинцы,  размер 40-48 . Сетка',
#  'Кроссовки кроссовки бу размер 22 в см 12',
#  '11.069 Начальный столб, балясина (L1100 осн.30х30) Начальный столб, балясина, сталь. Ковка. Используется как начальный столб при изготовлении лестничных ограждений, балконов, ворот и других изделий художественной ковки.',
#  'Туфли Carlo Pazolini Carlo Pazolini удобные туфли, почти в новом состоянии. Натуральная кожа, замша. Покупала за 6000 т.',
#  'Комбинезончик с длинными рукавами Выполнен из хлопка/\nВ наличии/\nНовый',
#  'Коттедж 150 м² на участке 7 сот. Продается отличный коттедж 2015 года постройки, навес под транспортное /\nсредство./\nУчасток 7 соток земли, во дворе имеется теплица, насаждения. Отличная /\nбаня на дровах 6*3, водопровод, имеются теплые полы./\n/\nОбщая площадь 150 м.кв., 1 этаж: кухня - гостиная, кабинет, котельная, /\nприхожая, коридор, с/у, теплые полы на 1-м этаже./\n/\n  2 этаж: 3 спальных комнаты, гардеробная, с/у, отопление от радиаторов. /\nХорошая внутренняя отделка./\n/\nКоммуникации: Газовое отопление, центральная канализация, водопровод / /\nскважина 55 м., электричество 220-380 15 кВт., проводной Интернет, видео /\nнаблюдение, охранная сигнализация./\n/\nСобственник. Вопросы по телефону.',
#  'Ботинки мужские Ботинки не много б/у, еврозима, мягкие, искусственная замша.',
#  'Продам обувь Продам обувь для мальчика в очень хорошем состоянии,не промокают.стильные,торг уместен',
#  'Ботиночки весеа осень Ботиночки в отличном состоянии. 23 размер. Подходят для небольших морозов до -10.',
#  'Комбинезон Теплый с подкладом. Состояние отличное.',
#  'Детские часы Породам детские часы для мальчиков и девочек показывают время и помимо этого могут проецировать 24 изображения  из мультфильмов Робокар Полли и Холодное Сердце. Смотреть и забирать  на Молодогвардейцев.',
#  'Гараж, 12 м² продаю гараж, имеется смотровая яма, погреб, электричество, стеллажи, рядом с Красными казармами.',
#  'Трикотажное платье Продаётся плотное трикотажное платье. Размер L, цвет черный, состояние отличное. Без молнии и пуговиц. Могу переслать в любой город почтой.',
#  'Кукла- шкатулка Продам куклу-шкатулку , высота 30 см.,каркас- клееный картон , окткрывается юбочка. Возможно изготовление на заказ.',
#  'Дом 35.9 м² на участке 30 сот. Продаю дом в хорошем состоянии.Две светлые комнаты,печное отопление,есть русская печь.Баня требует небольшого ремонта.Рядом есть речка.',
#  'Декор, цифра помпоны Продам объемную цифру помпоны, все делала сама из салфеток!',
#  'Инвалидное кресло Продам инвалидное кресло.',
#  'Кроссовки Puma Disc мужские Закрыли магазин! Распродаём товар! Крутые кроссовки, ограниченная коллекция, по очень низкой цене!/\nЗаходите в мой профиль, там много модной мужской одежды!',
#  'Продам трансформатор (в отличном состоянии) Продам трансформатор ТСДЗ-63/038УЗ (в отличном состоянии). Напряжение 380V.Номинальная мощность 63кВа.',
#  'Блины для штанги MB Barbell 2 x 20 кг Абсолютно новые блины./\n 26" внутренний диаметр/\nMB Barbell качественная резина, металлическая втулка, не пахнут.',
#  'Гжель, Хохлома, Береста. матрешки предлагаем Вашему вниманию  товары народных художественных промыслов России. В продаже разнообразные товары : скатерти, полотенца, рушники, посуда.    Большой выбор шалей, платков, палантинов, шарфов.  Огромный  выбор сувениров: русские матрешки, куклы в национальных нарядах, часы, Жостовские подносы, Гжель, Хохлома, Береста Павлово-Посадские платки, шкатулки федоскино, Палех  Одежда  в русском стиле.  Выбор платьев изо льна и штапеля в пол, разнообразные юбки, в том числе и  Барановские юбки и много других разнообразных предметов в исконно русской стилистике.',
#  'Шорты Спортивные шорты, новые. Размер 42/44. Р-он к/т "Шипка".',
#  'Картина В прекрасном состоянии',
#  'Сарафанчик Легкие сарафанчики на годовасиков)',
#  'Новая безрукавка НОВАЯ безрукавка 110-116 рост/\nНомер по каталогу: 297517399',
#  '1-к квартира, 30 м², 3/5 эт. Срочно сдам малосемейку квартирного типа, можно лицам из ближнего зарубежья.',
#  'Платье Продаю платье в  отличном состоянии!',
#  'Новое платье Mango Новое платье Mango, размер С, на российский 42-44, заказывала из германии, мало',
#  'Пальто р.50 хорошее состояние. на бирке 50 размер',
#  'Жилетка Продам жилетку из искусственного меха, цвет серый с кожаными вставками, теплая, можно одевать сверху куртки, смотрится богато и стильно!',
#  'Ремонт -установка сан.тех. оборудования Канализация, водопровод, отопление.',
#  'Платья, сарафаны Сердечками длинна 44 см, 150 руб./\nБелое длинна  46 см, 200 руб./\nПолосатое длинна  48 см, 200 руб.',
#  'Мастер на час Избавлю вас от проблем с электрикой и сантехникой. Произведу мелкий ремонт помещения.',
#  'Toyota Corolla, 1993 Продам надежный , крепкий, очень экономичный автомобиль . Машина на ходу. Стоит контрактный двигатель в ПТС указан. Машина хорошая не разу не подводила, бензин нюхает. Не так давно было поменяно сцепление и все подушки. Масло менялось своевременно (лил Хадо очень хорошее масло). Машина не насиловалась, ездили аккуратно.',
#  'Кровать детская кровать б/у в отличном состоянии.Удобная очень, крепкая, сделана на заказ, в мебельном ателье "Альпы". Под ней хранились игрушки в специальных контейнерах.Сделана труба хромированная, куда можно повесить шторки, тем самым закрыть игрушки, сделать более интересный интерьер или домик для ребенка, под кроватью еще полочка имеется. Ступеньки открыты, что тоже удобно. Ставили корзины с игрушками. Легко пользоваться....Служила 1,5 года. 18500р. Есть к ней хороший матрац 4000р.',
#  'Свитерок Продам свитер в отличном состоянии. Цвет темно синий./\nр-н Портовой.',
#  'Стиральная машина Samsung на запчасти Продам стиральную машину Samsung WW60H2220EW на запчасти,',
#  'Грузоперевозки Доставка грузов по району и краю по доступным ценам. Автомобиль Газель грузоподьемность 2 т. габариты кузова 4 х 1.8м.',
#  'Марка охраняемые млекопитающие фауны СССР 1977 марка охраняемые млекопитающие фауны ссср 1977',
#  'Детская кроватка Фея Кроватка в идеальном состоянии, пользовались всего пару месяцев (кроватка стояла у бабушки, чтобы оставаться с ночевкой). Не погрызана, не изрисована и тд. Хранилась 2 года дома, в кладовке. Стоит в разобраном виде, за подробными фото пишите в вибер или вацап',
#  'Витрина 188х220х45 В отличном состоянии с открывающимися стёклами. Торг',
#  'Продам скутер Omaks Virtuality 125сс Отличный скутер! Состояние хорошее! Есть небольшие зарапины и трещины! На фото можно разглядеть! Прошлой осенью была замена поршней с кольцами! Аккумулятор старый но заводиться как со стартера так и с ножки!! После зимы завели все работает хорошо!  Торг!',
#  'Кровля Кровельные работы любой сложности',
#  'Самокат zimer z-65 Самокат поможет ребёнку не только весело провести время, но и развить координацию, ответственность и физическую форму. Три колеса помогают держать равновесие. Яркий дизайн и мигающие колёса привлекают внимание. Самокат очень прост в использовании, он складывается и удобен для транспортировки. Изготовлен из безопасных материалов./\n /\nВес 1 шт.: 1\xa0кг/\nРазмеры 1 шт. (ДxШxВ): 59 x 14 x 26\xa0см/\n /\nМагазин «СимбаЛэнд» город Михайловка ул.Республиканская 28 с 9-00 до 20-00',
#  'Продам куртку Продам куртку',
#  'Малахитовые серьги и браслеты Продаю серьги и браслеты из поделочного малахита. Серьги с английской застежкой.',
#  'Костюм новый Костюм велюровый с биркой,не подошёл размер.',
#  'Отделка Выполним работы по отделке квартир коттеджей и домов . Сантехника, электрика, отопление, теплый пол. Быстро качественно и с гарантией!!!',
#  'Radeon HD6970 Видеокарта в идеальном состоянии !/\nНе разгонял !',
#  '1-к квартира, 43 м², 7/9 эт. Сдается однокомнатная квартира лен.проекта, частично меблированная. Есть все необходимое для проживания (стиральная машина, холодильник, пылесос, ТВ). Оплата 15000 руб.  + свет и вода по счетчикам.',
#  'Домик Смурфеты и 5 смурфов Замечательный домик маленькой  Смурфеты порадует вашего ребёнка. Сам домик,дверь и все окошки открываются. В домике имеется мебель. Идеальный подарок для девочки 4-7 лет. Сохранился в идеальном состоянии. На вид совсем новый,только без коробки.',
#  'Прогулочная Коляска Chicco Simplicity Коляска прогулочная SimpliCity модель для города и торговых центров. Компактная, маневренная и легкая, она станет отличным транспортным средством в случае, если вы предпочитаете гулять по оживленным улицам или же пользоваться во время променада общественным транспортом. Для большего удобства здесь предусмотрена функция складывания одной рукой, а незначительный вес коляски позволит вам самостоятельно переносить ее в случае необходимости. Ребенку же понравится просторное сидение с мягкой спинкой и подножкой./\n/\nОСОБЕННОСТИ:/\n/\nлегкое шасси/\nмеханизм складывания - книжка/\nпередние сдвоенные поворотные колеса с фиксаторами/\nзадние одинарные колеса/\nножной тормоз/\nфункция складывания одной рукой/\nширокое сидение/\n5-точечный ремень безопасности с накладками и центральным замком/\nсъемный бампер с накладкой/\n4 положения спинки (включая горизонтальное)/\nширокий козырек со смотровым окошком/\nбольшая корзина для покупок/\nкомпактные размеры в сложенном виде/\nтекстильные элементы можно стирать при 30 градусах/\nВ комплекте накидка на ножки и дождевик. Все механизмы в рабочем состоянии .',
#  'Торговое помещение, 78 м² Продам магазин с Арендаторами-ул.Щорса,76 : 78 кв.м., всего за 4 500 000 руб. Хорошее предложение для инвестирования- аренда : 50 000 руб./мес. Собственник!!',
#  'Прийму бой Прийму бой на дорогу',
#  'Xbox 360 +5 игар фифа15,16 мартол комбат 9, гта5,асассин 4, и три диска Фифв 13 гта 4 видмак3',
#  '1-к квартира, 34.7 м², 2/4 эт. Продается 1 комнатная квартира в 4 этажном доме. Дом 4 года, как построен.',
#  'Xbox 360 500 гб Продам в отличном состоянии , в комплекте проводной и беспроводной геймпады (зарядное устройство для беспроводного), гарнитура , два диска . Вообщем полный комплект, но без Kinect.',
#  'Потолок подвесной armstrong accord 60x60 Потолочные плиты серии Эконом. Звукопоглощение 0,07-0,25, Звукоизоляция 15- 17 Дб, Влагостойкость 70%/\nПрименение подвесных потолков позволит:/\nСделать невидимыми, но при этом доступными, различные инженерные системы и коммуникации./\nВстраивать в них модульные осветительные приборы, вентиляционные решетки и размещать на них головки систем пожаротушения./\nНивелировать рельефный базовый потолок и, наоборот, создать рельефный./\nсохранение формы даже в очень влажных помещениях./\nЦена за 1 плитку. В коробке 24шт. Продажа от одной коробки.',
#  '1-к квартира, 52 м², 3/25 эт. Продаю 1-к квартиру от подрядчика в ЖК "Дельфин". Застройщик ООО "Выбор". Дом сдан!!! Отличная планировка. Квартира с видом на водохранилище!',
#  'Основы электромагнитной совместимости ',
#  'GAP Оригинал, желетка пуховая XS Новая, покупали в фирменном магазине GAP по курсу за 10000р, за столько и попадаю, причина не подошел размер, xxs по факту xs-s',
#  'Аэрогриль Подарили аэрогриль. Использовали всего пару раз.',
#  'ГАЗ 31105 Волга, 2004 тип двигателя газ,бензин,обмен на бортовой УАЗ',
#  'Темно-синяя куртка 6-9 мес Продам куртку в идеальном состоянии для мальчика 6-9 мес. Мы росли по нормам и носили ее до года. Капюшон и желании можно отстегнуть. На ребенке смотрится очень круто./\n Фото не грузится, смогу прислать в вибере или ВК по желанию.',
#  'Кухонный шкаф В отличном состоянии',
#  'Демисезонные ботиночки.размер 39 ',
#  'Платье, новое Платье новое, расшито стразами, натуральный атлас. Очень красивое ...',
#  'Roverpad air s7.85 3g Модель RoverPad Air 7.85 Операционная система Android 4.x+ Внешний вид, корпус Материал корпуса пластик Экран Диагональ экрана 7.85" Разрешение экрана 1024x768 Плотность пикселей 163 ppi Технология изготовления экрана IPS Тип сенсорного экрана емкостный Мультитач-экран есть Система Производитель процессора MediaTek Модель процессора MediaTek MT8389 Количество ядер 4 Частота процессора 1.2 ГГц Конфигурация процессора 4x Cortex-A7 1.2 ГГц Видеопроцессор PowerVR SGX544MP2 Оперативная память 1 Гб Встроенная память 16 Гб Слот для карты памяти есть Тип карты памяти micro SD Максимальный размер карты памяти 32 Гб Беспроводная связь Модуль сотовой связи 3G Поддержка двух сим-карт нет Поддержка Wi-Fi есть Стандарт Wi-Fi 802.11b/g/n Bluetooth есть Версия Bluetooth 4.0',
#  'Обмен места в детском саду Обменяю место в детском саду N72 на детский сад N74 или N77. Ребенок июль 2014 г.р.',
#  'Компрессор воздушный fubag продам ременной компрессор с ресивером 100 литров производительностью 400 литров в минуту, два цилиндра б.у 1 год, состояние отличное',
#  'Грузоперевозки длинномер бортовой открытый Предлагаю услуги по перевозке грузов в любом направлении (по РБ, РФ). /\nДлинномер бортовой открытый, длина кузова 13,6 м, стойки, массой до 20 т. /\nТранспортные услуги: Перевозка сруба (баня, дом), пиломатериалов (доска, брус), железобетонных изделий (плиты, блоки, перемычки), металлоизделий, металлопроката, станков, стройматериалов (кирпич, пеноблоки, цемент, сухие смеси).',
#  'Футболки, кофты, свитшот, боди на мальчика. Пакето Вещи пакетом на мальчика. /\n2фото: футболка ПОЛО на 1,5-2 года. /\n3фото: футболка с оранжевым воротом. Примерно до года./\n4фото:  футболка ДЖИ ДЖЕЙ. До роста 70 см./\n5 фото: майка КРОКИД. На 1,5-2 года./\n6 фото: кофточка в зеленую полоску(есть пятна от бананов). До роста 70 см./\n7 фото: боди ЛЕО. До 68см./\n8 фото: свитшот на 1,5-2 года./\n9 фото: пинетки ДИСНЕЙ. По стельке 11,5 см.',
#  'Уголок на выписку Продам уголок под одеяло ( прикрыть лицо малыша). НОВЫЙ!!! Не пригодился, покупала за 450 руб в Чудо Юдо, цвет: чисто белый.',
#  'Горящий Китай, о.Хайнань 9 ночей 4-5 звезд ☀🌴ГОРЯЩИЙ КИТАЙ, О. ХАЙНАНЬ!!!/\n✈Вылет 29 марта на 9 ночей/\n🔥Отели 4-5* с завтраком за 30900 руб. на чел.!!! /\n🌍Много отелей на выбор. Без доплат!/\n❗В стоимость тура входит: перелет, трансфер аэропорт-отель-аэропорт, проживание в отеле, питание по туру , мед.страховка. /\n/\nПо отелям запрашивайте. /\nБуду рада ответить на вопросы в вотс ап или по телефону',
#  'Nissan Mistral, 1995 Отс,7мест, CD ченджер, люк, максимальная комплектация, новая зимняя резина в подарок ,турботаймер, музыка MP3, в родной краске,',
#  'Куплю 2-к квартиру Куплю 1-ю или 2-х комнатную квартиру не дорого,  р-н ПТФ, старый р-н и район аэродрома не предлагать.',
#  'Колонки для компьютера Колонки Genius',
#  'Zte blade a510 Телефон в хорошем состоянии, есть небольшие сколы. Документы также имеются',
#  'Кукла Elsa (Frozen) новая, в коробке/\nни разу не доставалась из нее./\n/\nпроизводитель Дисней/\nкуплена в США',
#  'Егэ по русскому языку Сенина Н.А. Русский язык . ЕГЭ 2006 .вСТУПИТЕЛЬНЫЕ ЭКЗАМЕНЫ. Справочные и дидактические материалы, тексты.',
#  '1-к квартира, 33 м², 3/9 эт. в продаже 1-я квартира, с ремонтом остается вся мебель, техника, сплит система, развитый район, школы, д/сады, гипермаркет, остановки, поликлиника, церковь, парк. Цена занижена в связи с срочностью продажи!!!!',
#  'Suzuki GSF 750 Продаю мотоцикл в хорошем состоянии. Двигатель и коробка без нареканий,как и положено японской технике.Лако-красочное покрытие радует глаз.Резина перед DUNLOP sportmax новая,зад MICHELIN pilot road2 износ процентов 15.АКБ-куплен в том году.Цепь прошла не больше 1000 км , звезды в хорошем состоянии.В общем мот 96 г.в в состояни 2006г.в.От мота не избавляюсь.Он реально хорош.Просто жизнь идет и хочется попробовать что -то другое',
#  'Кольцо из красного золота С фианитами Артикул: кц0015120\xa0/\n /\nРазмер: 20.5 /\n /\nПроба: 585/\n /\nПол: Женский /\n /\nЦвет металла: Красный/\n /\nВставка: Недрагоценные камни /\n /\nВес: 3.9/\n /\nВид: Новый /\n /\nПроизводитель: Москва,Зеленоград',
#  'Кастюм весна-осень Кастюм "шалуны" наполнитель изософт. до -5.  размер на рост 90-98. писать в ватцап.',
#  'Жеребец 2006года Продаю :жеребец 2006года Выбор (Блю-Ледей -Весталка)  жеребец на племя,  для улучшения породы , крупный коститстый.Торг за срочность',
#  'Коляска-трость bambola HP-312C "жужа Бесплатная доставка  Характеристики : /\n— Предназначена для детей с 6 месяцев до 3 лет./\n— Легкая и прочная алюминиевая рама складывается "тростью"./\n— Объемный и широкий капюшон опускается до бампера./\n— Карман для мелких вещей на задней части капюшона./\n— Капюшон с забавным принтом./\n— Удобная широкая спинка легко раскладывается в 3 положениях - от сидячего до, практически, лежачего положения./\n— Мягкая подножка регулируется в нескольких положениях, включая горизонтальное положение для сна и отдыха.\xa0/\n— 3-х точечные ремни безопасности с надежным замком и мягкими плечевыми накладками./\n— 8 колес из долговечной псевдо-резины, установленны попарно./\n— Передние колеса поворотные с фиксаторами хода в одном положении./\n— Тормозная система удобно вынесена на задние колеса./\n— Плотная и прочная обивка коляски легко моется./\n— Удобные двуцветные родительские ручки./\n— Разъемный мягкий бампер-ограничитель./\n— Матерчатый паховый ограничитель от скатывания, крепится двумя кнопками./\n— Предусмотрена матерчатая корзина для покупок и вещей./\n— Предусмотрена ручка для переноса коляски в сложенном виде./\n—  Размеры и вес : В разложенном виде : 80 * 50 * 104 см. Диаметр колес : 15,5 см. Вес коляски : 6,4 кг.',
#  'Стелс 500gt Продам квадроцикл 2012г с пробегом 1485 км. Пластик целый, рама не варенная, колёса с минимальным износом,  все  жидкости поменяны, прошприцован, тормозные накладки в норме. Установлено ручное переключение полного привода без электронники,  ручник перенесён на левую рукоятку блокирует все 4 колеса, принудительное вкл вентилятора с кнопки, задний багажник смещен назад для удобства пассажира, стойки переделаны под  "мягкие",  стоит подогрев ручек и курка газа. Минусы аккумулятор еле жив,  люфт в ступичных подшипниках переднее левое и заднее правое не критично но лучше заменить. Торг у капота. Обмен не интересует.',
#  'Мультиварка redmond RMC-M4510 Продается новая Мультиварка REDMOND RMC-M4510, 1000Вт, черный/серебристый./\nСэкономить время при приготовлении пищи и гарантированно получить отличный результат вам поможет мультиварка REDMOND RMC-M4510. Она поддерживает 40 программ приготовления, среди которых 27 ручных и 13 автоматических, а также режим "Мастершеф Лайт". С его помощью вы сможете в процессе приготовления менять параметры на свое усмотрение. Чаша мультиварки REDMOND RMC-M4510 за счет антипригарного покрытия предотвратит прилипание пищи. Для максимального комфорта пользователя предусмотрена возможность откладывать начало приготовления до 24 часов, поддерживать приготовленное блюдо теплым, а также отключать звуковые сигналы. Последнее особенно пригодится в доме, где есть маленькие дети. Эта элегантная модель станет не только вашим помощником на кухне, но и настоящим ее украшением.',
#  'Коляска Tutis Zippy Sport Plus 2 в 1 шоколад Продам очень легкую коляску в отличном состоянии. Цвет очень красивый шоколад идеально подойдет и мальчику и девочке. Эта супер модель о покупке которой мы не пожалели. Рекомендую и вам. В комплекте стильный рюкзачок, дождевик и москитная сетка.',
#  'Очки детские оправа Оправа для ребенка 3-5 лет, RD 49. ax170,сейчас стоят линзы R -1,75,_L-2. Новые в оптике 2т.р.',
#  'Рубашки 4-5 лет Рубашки в отличном состоянии на возраст 4-5 лет, тоненькие, х/б./\n200 руб/шт',
#  'Детская хоккейная форма Комплект хоккейной формы на ребёнка 7-9 лет. Отличное состояние!',
#  'Сладкий подарок Фиолетовая композиция (коробочка конфет) розовая композиция (плитка шоколада)',
#  'Боди и слип Продам 3 боди и слип все фирмы cool club, покупали в магазине Смик. Боди 300 и слип 300. Размер 74.',
#  '1-к квартира, 34 м², 3/5 эт. Продам 1-к квартиру с отличным , окна пластиковые, межкомнатные двери заменены, хорошая новая дверь, натяжные потолки, сантехника заменена. В квартире остается  кухонный гарнитур, за дополнительную плату оставлю мебель. Рядом садик, школа, магазины. Отличный вариант для семьи с ребенком.',
#  'Грузоперевозки Грузоперевозки 250час',
#  'Босоножки Продам Босоножки, очень эффектные и красивые, с нарядным галстуком впереди. Одевала только на торжества несколько раз. В отличном состоянии, поменяны набойки. Материал - ткань. Цена 800руб.',
#  '3 копейки 1970 ',
#  'Продам брюки детские Брюки льняные',
#  'Сапожки Утеплены натуральным мехом. Состояние очень хорошее. По стельке около 16-16,5см./\n15мкр',
#  'Комплект на выписку Продам комплект на выписку зима-весна.В комплекте тёплое одеало,комбинезон-конверт, пеленка и тёплая шапочка.',
#  'Демары Состоянии на 5, теплые, удобные',
#  'Тески станочные В хорошем состояние',
#  'Маска сварочная хамелеон новая Продам маску сварочную новую не разу не пользовалась',
#  'Продам брюки голубые Продам новые брюки голубые. Абсолютно новые. Внизу на резинке. Рост 122-128( большемерят). Не на плотного мальчика. Есть такие же на рост 128-134. По 250 каждые. Верхние печеры',
#  'Пиджак фирмы mexx Женский пиджак брендовой фирмы MEXX. Цвет тёмно-серый, на двух пуговицах, на рукавах по 4 пуговицы, отрезной по талии, в идеальном состоянии, надевался один раз. Европейский размер - 38.',
#  'Стиральная машина Samsung все агрегаты в рабочем с Все агрегаты в рабочем состоянии, требуется замена крестовины барабана.',
#  'Джинсовка короткая',
#  'Дверь входная пластиковая Дверь пластиковая , тройной стеклопакет. Торг',
#  'Ботинки весну-осень В хорошем состоянии.Для первых шагов.СКОРОХОДОВ.',
#  'Комбинезон-песочник "Hello Kitty" рост 62-68 Состояние отличное. И еще много новой (в т.ч. брендовой) и б/у детской одежды, обуви, мебели, игрушек, аксессуаров для детей в комиссионном магазине (на ул. 1-й Конной Армии,36, конечная 40-й маршрутки Сельмаш) с 10-00 до 17-00 час. без выходных). Очень дешево! Страничка в Одноклассниках: Детская комиссионка Ростов-на Дону. Страница в Контакте: Татьяна Ежик. Пишите, звоните, сообщим адрес и сайт, ответим на все вопросы по наличию товара и размерам. Высылаем товары почтой по России.Принимаем товары на комиссию. Уважаемые покупатели, уточняйте наличие товара по телефону.',
# ...
#  '1-к квартира, 30 м², 9/9 эт. Продам 1 МС, на ул. Юбилейная. Квартира находится на 9-м этаже 9-ти этажного кирпичного дома, не угловая, общая площадь 30 кв.м. Квартира в отличном состоянии (окна ПВХ, железная входная дверь, сан.техника хорошая). В собственности более 3-х лет. /\n/\n#объект в нашей базе №221007#',
#  'Лестница Продаю деревянную лестницу,хорошая,крепкая,не шатается, лежит-место занимает. Длина 2.8м. В огороде точно пригодится.',
#  'HP Deskjet Ink Advantage 1515 - МФУ (принтер, сканер, копир)/\n- 4-цветная струйная печать/\n/\nПолностью рабочий принтер. Отсутствуют картриджи.',
#  'Косуха Косуха кожаные рукава, вставки из чёрной джинсы ,2 кармана ,завышенные плечики,леопардовая подкладка ,идеальное состояние ,к переду удлинение ,молния ,New Yorker',
#  'Кожаные ботиночки Стильные, натуральная кожа, надеты 1 раз. Размер 38.',
#  'Кожаные босоножки для принцессы Полнота регулируется липучками',
#  'Куртка-пальто весна-осень на девочку Куртка-пальто весна-осень на девочку. Ярко розовая. Рост 116. С капюшоном. Верх - болонь. На тонком синтепоне. Состояние очень хорошее.',
#  'Комбинезон Продам весенний комбинезон для мальчика на рост 62-68.Фирма некст,носили очень мало.Цвет синий, просто на фото засветился немного',
#  'Резиновые сапожки Продам резиновые сапожки для девочки. В хорошем состоянии.',
#  'Новый сборный бассейн Гибралтар J-4000 5.5х1.35м Гибралтар являются эксклюзивным видом бассейнов, который не имеет контрфокусов. Благодаря отстутсвию контрфокусов бассейны занимают гораздо меньшую площадь, чем предыдущие модели. Ширина фактически занимаемой площади сокращается на 2,2м! Покрытия XXI века BAKE KOT и PROTECTOLOG применяемые в моделях Гибралтар обеспечивают надежную защиту металлических составляющих от корозии, царапин и ультрафиолета./\nБассейны серии Гибралтар в отличии от предыдущих моделей имеют самые широкие боковые стойки 230мм и верхний кант 230мм, обеспечивающие максимальную механическую жесткость конструкции бассейна./\nНовейшие конструкторские решения, воплощенные в этой модели создали смесь уникального дизайна и высокой прочности./\nВ комплекте: песковый фильтр с четырех / шестипозиционным вентилем и циркуляционным насосом, фракционны кверцевый песок, лестница, устройство сбора грязевых частиц с поверхности воды (скиммер), форсунка подачи воды, соеденительные шланги, инструкция по сборке бассейна./\nВысота борта 1,35 м/\nДиаметр 5,5 м/\nОбъем 30,8 м в квадрате/\nколичество упаковок 9/\nОбщий вес 283 кг/\nБАССЕЙН АБСОЛЮТНО НОВЫЙ, УПАКОВАН, НЕ РАЗУ НЕ УСТАНАВЛИВАЛСЯ, НЕ СОБИРАЛСЯ!!! ПРИВЕЗЕН ИЗ КАНАДЫ!',
#  'Куртка под костюм Продаю мужскую куртку. Идеально подходит под костюм, прикрывает пиджак. Куртка делового стиля, но при желании можно носить и под джинсы. Если подойдет возможен небольшой торг.',
#  'Тумба под телевизор Без торга',
#  'Продаются диван и кресло Продаются новые диван и кресло производства Санкт-Петербург в отличном состоянии, на гарантии. Механизм  раскладушки выдвижная книжка (можно ставить прямо к стене). Ширина 215, спальное место дивана 190 на 140. Куплен комплект за 38 тыс600 руб. Товарный чек имеется',
#  'BQ Comfort 2300 — /\n— поддержка двух SIM-карт/\n— экран 2.3", разрешение 320x240/\n— камера 0.30 МП/\n— память 32 Мб, слот для карты памяти/\n— Bluetooth/\n— объем оперативной памяти 32 Мб/\n— аккумулятор 1400 мА⋅ч/\n— вес 101 г, ШxВxТ 59x123x15 мм/\n— радио',
#  'Пальто Сиреневое пальто, демисезонное. Размер 44, рост до 155.',
#  'Набор клупов Продам или поменяю на ушм маленькую или лобзик',
#  'Куртка джинсовая Состояние отличное',
#  'Ботинки демисезонные для мальчика Ботинки демисезонные утепленные, в отличном состоянии. Очень удобно одевать, застёгиваются на молнию легкие. Длина по стельке 19,5 см.',
#  'Кирпич красный фундаментный Кирпич красный фундаментный марка 125-150, полнотелый, четкая геометрия от ведущих производителей области по цене от 8,30 руб/шт., доставка транспортом предприятия без посредников, документы любые, форма оплаты любая. Так же доставляем песок, щебень, отсев,грунт.',
#  'Варенье.лечо.салаты помидорчики..огурчики отменные-вы таких не ели..икра кабачковая..все стерильно..с дегустацией..для себя готовили-не сьесть-всяко ..маринад легкий..можно обмен на DVD диски',
#  'Платья б\\у платья б\\у в отличном состоянии надеты все от одного до трех раз, цена от 400 руб',
#  'Платье ',
#  'Часы sandr Надежные,водонепроницаемы часы с подсветкой./\nПослужат отличным аксессуаром.',
#  'iPhone 6s 16gb розовый идеал рст Айфон на 16 Гбайт /\nЦвет розовое золото/\nПолный комплект, наушники не распаковали/\nКуплен в Мвидео /\nСостояние, как с витрины/\nС первых секунд в пленках/\nТОРГ',
#  'Валенки р. 28',
#  'Продам крутую юбку ',
#  'Кенгуру переноска Почти не пользовались',
#  'LADA Granta, 2013 Автомобиль в отличном внешнем и техническом состоянии!!!/\n /\n\xa0КОМПЛЕКТАЦИЯ:/\n/\n- Магнитола MP3/CD/USB/AUX/DVD-4 КОЛОНКИ\xa0/\n- Крепления для детских сидений ISOFIX/\n- Блокировка задних дверей от открывания детьми/\n- Иммобилайзер/\n- Центральный замок/\n- Антиблокировочная система тормозов с усилителем экстренного торможения (ABS+BAS)/\n /\n- Подушка безопасности водителя/\n- Электронная система распределения тормозных усилий (EBD)/\n- Воздушный фильтр салона/\n- Тонировка стекол/\n- Cигнализация с обратной связью/\n- Электростеклоподъемники передних дверей/\n- Обогрев заднего стекла/\n/\nПредусмотрены программа кредитования автомобиля (одобрение в течении 1 часа) и\xa0обмен авто!!!Автомобиль был принят по системе trade in официальным дилером LADA, автосалоном Автосоюз./\nАвтомобиль прошел проверку на наличие штрафов и обременений!!!/\nГАРАНТИЯ ЮРИДИЧЕСКОЙ ЧИСТОТЫ СДЕЛКИ!!!!!',
#  'Ботинки Состояние отличное(носили меньше месяца).Легкие, классные, не промокают.ТОРГ',
#  'Кроссовки Лёгкие кроссовки на ногу 16 см./\nБ/у , но в хорошем состоянии, липы крепкие.',
#  'Спил деревьев обрезка деревьев услуги альпинистов спил деревьев разной сложности/\nобрезка деревьев - садовых,аварийных нависающих над строениями проводами,удаление в стесненных условиях больших деревьев по частям с завеской фрагментов цены договорные',
#  'Пакеты фасовочные Новый',
#  'Машинка для приготовления равиоли Машинка для приготовления равиоли и раскатывания теста для пасты /\nЗачем покупать равиоли, если можно сделать их дома? С новым товаром Gusto Pasta Machine and Ravioli Maker это просто. Удобная в использовании, легкая и компактная пресс-машина поможет вам быстро приготовить любимые блюда. /\nЛюбителям домашних равиоли больше нет необходимости проводить на кухне долгие часы за нарезкой теста, раскладыванием фарша и лепкой. Равиоли из пресс-машинки получаются ровными и красивыми, легко отделяются друг от друга. /\nИтальянские равиоли, представленные в самых разных кухнях мира, и любят их многие гурманы. Вот только времени на их лепку уходит столько, что для большинства из нас это блюдо в домашнем приготовлении оказывается в разряде недоступной роскоши. /\nС нашей машинкой, вы сможете без труда радовать себя этой роскошью. /\nПринцип работы: /\nГотовый пласт складывается пополам и помещается между валами насадки, затем свободные концы распределяются по роликам. Начинка помещается в отведенное углубление чайной ложкой и добавляется по мере необходимости. /\nЗаготовка для равиоли зажимается между валиками машинки, благодаря вращению ручки, пласты теста соединяются между собой и надрезаются. /\nГотовые равиоли выходят из машинки в виде ленты, которую необходимо разобрать на составляющие части. Равиоли получаются квадратной формы 30 х 30 мм, с красивыми фигурными краями/\nТехнические характеристики /\nХромированная поверхность. /\nНикелированные ножки. /\nКомпактный дизайн. /\nМеханизм для крепления к поверхности стола. /\nВес: 2,23 кг.',
#  'Бандаж Orlett на коленный сустав RKN-202 XL Бандаж Orlett на коленный сустав ортопедический, с металлическими шарнирами предназначен для иммобилизации коленного сустава, обеспечивает сильную степень фиксации, боковую стабилизацию коленного сустава. Два полицентрических шарнира обеспечивают нормальную биомеханику коленного сустава при движении, ограничивают избыточную боковую подвижность и переразгибание коленного сустава. Ношение бандажа способствует уменьшению отека и улучшению кровоснабжения мягких тканей, прилегающих к суставу./\n/\nНазначения/\n/\nконсервативное лечение деформирующих остеоартрозов коленного сустава на начальной стадии заболевания;/\nнестабильность коленного сустава;/\nнефиксированные деформации коленного сустава;/\nтравмы коленной чашечки (надколенника);/\nстабилизация коленного сустава после снятия гипсовых повязок;/\nповреждения менисков;/\nболевой синдром после травм и операций на коленном суставе (если не противопоказан тепловой эффект);/\nреабилитация после травм и восстановительных операций на менисках;/\nпрофилактика травм сустава при занятиях спортом и выполнении работ, связанных с нагрузкой на коленный сустав./\nОсобенности/\n/\nВ модели бандажа Orlett, арт. RKN-202 предусмотрен полулунный пелот для дополнительной фиксации коленной чашечки. /\n/\nМатериал бандажа (неопрен) оказывает согревающее воздействие на сустав, способствуя улучшению кровообращения. /\n/\nДополнительные фиксирующие ремни с застежками-липучками "Велкро" позволяют закрепить изделие на ноге в правильном положении. /\n/\nНошение бандажа не вызывает аллергии и кожных реакций./\n/\nЦвета:\tчерный/\nРазмеры:\tS (27-30), M (30-33), L(33-36), XL(36-40), XXL (40-44),обхват в сантиметрах/\nПодбор размеров/\nДля корректного подбора ортеза Orlett на коленный сустав необходимо измерить сантиметровой лентой (плотно, но не утягивая) обхват под коленом./\nСогласно полученным результатом подобрать ортез Orlett по таблице подбора размеров/\n/\nОтличное состояние',
#  'Стулья ikea Продам 8 стульев в хорошем состоянии, использовались мало. Стулья складные и лёгкие.',
#  'Asus ZenFone 2 laser ze500kl 16гб Бу 1 год, сколов и трещин нет, телефон в отличном  состоянии, стоит защитное стекло',
#  'Покрывало-одеяло летнее Размер 160*215/\nбиюза/\nдвусальное',
#  'Куплю 2-к квартиру Куплю либо обменяю на двухкомнатную по октябрьской 6 этаж 3. С нашей доплатой.',
#  '2-к квартира, 38 м², 2/2 эт. Квартира уютная, чистенькая, теплая, светлая. АГВ.  Кухня с залом переделаны под "студию".  Вся инфраструктура рядом. Соседи все спокойные, алкоголиков и дебоширов нет. Место тихое и спокойное, рядом детские площадки. Есть парковка.',
#  'Мобильный станок для обточки локомотивных колёсных Компактный станок для обточки локомотивных колёсных пар/\n/\nПрочная конструкция станка позволяет производить полноценную обточку колёсных пар без их выкатки из под локомотива, и не требует специально подготовленного места обточки. Вращение обтачиваемой колёсной пары может осуществляться как собственной силовой установкой, так и внешним источником питания (сварочный трансформатор постоянного тока). Вес станка 60 кг.',
#  'Ремонт и обслуживание пвх окон Ремонт, обслуживание, замена фурнитуры. Замена уплотнителя. Установка миктопроветривания и детского замка. Замена стеклопакета. Замена подоконника.',
#  'Продается учебник продается учебник по химии за 10 класс /\nавтор: Габриелян, Маскаев. /\nВыпуск 2002 г',
#  'Sony PS3 Sony PS3 в отличном состоянии,продаю за ненадобностью,память 12gb-встроенные+жесткий диск на 160gb,в комплект входит два джойстика(состояние новых,не залипают,не тупят,играли мало),игра FIFA 2014,кабель hdmi,коробка.',
#  'Платье детское ',
#  'Платье Торг',
#  'Бюстгальтер Новый не подошел размер. Производство Беларусь. Размер 85В без поролона и пуш-ап.',
#  'Отдам кошку Отдам кошку в связи с аллергией. Возраст 1 год, по комплекции маленькая, умная к детям хорошо относится, не царапается ))) к лотку приучена.',
#  'Нетбук acer ze6 Процессор: Intel Atom N570 (1,66 ГГц) или N455 / N475 (1,66/1,83 ГГц)/\nЭкран: 10,1 дюймов, 1024x600 пикселей/\nВидео: Intel GMA 3150/\nОперативная память: 1 или 2 ГБ DDR3/\nЖесткий диск: 250 или 320 ГБ/\nКамера: VGA/\nКарт-ридер: для карт памяти SD/MMC/\nРазъемы и связь: Ethernet, Wi-Fi 802.11 b/g/n, Bluetooth 3.0 или 2.0+EDR и 3.5G/HSDPA/\nАккумулятор: 6-ячеечный, 4400 мАч/\nДоступные цвета: желтый (Banana Cream), голубой (Blueberry Shake), оранжевый (Papaya Milk) и розовый (Strawberry Yogurt).',
#  'Наливной пол Bergauf Осталось 8 мешков,после ремонта!!!отдаю за полцены',
#  'Куртка весна-осень ',
#  "Сапожки Демары Теплые сапожки  Demar Kid's с небольшим дефектом (молния застегивается!) Отдам за чисто символическую плату",
#  'Красивый номер мегафон Продам красивый номер:восемь девятьсот двадцать девять 00 888 09/\nПереоформление в офисе мегафон./\nТариф "всё включено м" можно сменить на любой.',
#  'Вывоз мусора,доставка самосвалом от 1т до 30 город-область,песок,щебень,чернозём,асфальтная срезка,опилки,',
#  'Юбка Kira Plastinina В идеальном состоянии, на талию 160-165',
#  'Итальянские туфли В отличном состоянии, одеты пару раз! Каблук 5см',
#  'Комплект на выписку для джентльмена Костюмчик на мальчика на выписку или крещение. Состояние отличное, одет всего пару раз. Также есть варежки на ручки. Второй комплект: пододеяльник, уголок, чепчик и распашенка. Есть голубая лента. Цена договорная.',
#  'Продам бутсы Adidas продам бутсы в отличном состоянии.отыграл 3 тренировки. Футбольные бутсы ADIDAS MESSI 15.1 FG/AG S74679 SR профессиональная, взрослая модель с подошвой, адаптированной для игры на жестких полях с натуральным, травяным газоном или синтетической травой. Верх отличается легкостью и мягкостью и выполнен из прочных, синтетических материалов, которые способствуют созданию удобной посадке бутс на ноге. Передняя часть стопы обладает оптимальной гибкостью. Дополнительное покрытие верхнего слоя messiTOUCH X-ray создает уверенное сцепление с мячом, позволяя эффективно работать с ним. Усиленный, полимерный каркас messiFRAME, являющийся частью линии шнуровки, охватывающий задник и проходящий по боковым панелям к подошве, удерживает стопу, придавая ей устойчивость при резких маневрах и поворотах. Симметрично идущая система шнуровки загзагообразной формы способствует плотной посадке, устойчивости стопы и дает возможность быстро подобрать комфортный уровень плотности посадки. Мягкая, внутренняя стелька из легкого, упругого пеноматериала обладает отличным свойством демпфирования ударных нагрузок, которые воздействуют на стопу при активном движении. Подошва с динамической системой шипов messiGAMBETRAX дает игроку уверенное сцепление и позволяет быстро набирать высокую скорость. Центральный шип декорирован стилизованным логотипом Messi.',
#  'Продам диск lara croft на psp ',
#  'Коттедж 150 м² на участке 12 сот. Продается чудесный коттедж в экологически чистом месте. Удобная планировка, 4 комнаты жилые, кухня и огромная гостиная приятно Вас порадуют. /\nГаз подключен к дому, позволит вам всегда жить в тепле, при этом не переплачивать./\nБольшой участок правильной формы./\nНа участке гараж./\nКачественная отделка "Под ключ", обои под покраску, ламинат, натяжные потолки. /\nВ поселке есть школа, детские сады, магазины./\nУдобная транспортная развязка, до Екатеринбурга можно доехать на автомобиле за 10-15 минут, много проходящих автобусов./\nИпотека возможна./\nРассмотрим все варианты обмена./\n/\nДоп. описание: водоснабжение: колодец, отопление: газовое, канализация: биотуалет (септик), также имеются: интернет, телевидение, Номер в базе: 1156100. Район: Монетный',
#  'Hyundai i30, 2012 Продается автомобиль  Hyundai i30. Был куплен в июле 2012г  у официального дилера. В отличном состоянии. Не битый, не крашеный. Пробег 59400 км. Из недостатков трещина на лобовом стекле и царапина на переднем бампере. Торг у капота.',
#  'Породам окно Глухое 1кам32 с.пакет, ш650в1440. Новое не подошло по размерам., помогу/\n с доставкой.',
#  ...]

# %%
# preprocess corpus
text_output = [clean_text(x) for x in text_input]
train_output = [clean_text(x) for x in train_input] 
test_output = [clean_text(x) for x in test_input]

# %%
def save_text(file_name, text_array):
    f = open(f'{plain_text_dir}/{file_name}.txt', 'w', encoding='utf-8')
    for item in text_array: f.write('%s\n' % item)

save_text('avito_text', text_output)
save_text('train_avito_text', train_output)
save_text('test_avito_text',  test_output)

# %% [markdown]
# ### Tokenize

# %%
token_dir = '../input/tokens'

# %%
# load data
def read_comments(file_name):
    file_name = f'{plain_text_dir}/{file_name}.txt'
    text_list = [x for x in open(file_name, encoding='utf-8')]
    pattern = re.compile(u' |\n')
    text = {word for text in text_list for word in re.split(pattern, text.strip())}
    return text

# tokenize words
def tokenize(text_cleaned):
    word_tokenizer = Tokenizer(filters='', lower=False)
    word_tokenizer.fit_on_texts(text_cleaned)
    return list(word_tokenizer.word_index.keys())

# save data
def save_tokens(tokens):
    save_name = f'{token_dir}/avito_tokens.txt'
    file = codecs.open(save_name, 'w', 'utf-8-sig')
    for i in tokens: 
        file.write(i +'\n')
    file.close()

# %%
text = read_comments('avito_text')
tokens = tokenize(text)
save_tokens(tokens)

# %%
with open(f'{token_dir}/avito_tokens.txt', encoding='utf-8') as token_text:
    tmp = [next(token_text) for x in range(50)]
print(tmp)
# Out:
# ['\ufeffслезак\n', 'пoклeйкa\n', 'вощдушный\n', 'zxcv234\n', '1пинетки\n', 'невыпирает\n', 'водаканал\n', 'электроэпергии\n', 'ljm\n', 'фулатх\n', '7700тыс\n', 'хрущевка\n', 'обнавлениия\n', 'патиной\n', 'hkx\n', 'авподатчиком\n', 'адьютанты\n', '50х35х6\n', 'вoзрaст\n', 'скандинавскай\n', 'knortiba\n', 'углегорского\n', 't90\n', 'закрепленый\n', 'миротворческие\n', '33w\n', 'lidellen\n', '84341\n', 'рво1\n', 'шерек\n', 'окисляеться\n', 'подвязав\n', 'ниагара\n', 'новомосковская\n', 'производительdeceuninck\n', 'рарантируем\n', '800900\n', 'camorder\n', 'в4с\n', 'rj60\n', 'развешивай\n', 'квашеная3л\n', 'задниe\n', 'с2209\n', 'пневмогидравлическим\n', 'зуевскими\n', 'amvei\n', 'рм420\n', 'новомосковсго\n', 'эскадренный\n']

# %% [markdown]
# ### create FastText embeddings on raw text

# %% [markdown]
# ```
# #!/bin/bash
# DATA_DIR='../input'
# EMBED_DIR='../input/embeddings'
# TOKEN_DIR='../input/tokens'
#
# rm_first_line()
# {
#   FILE_NAME=$1
#   tail -n +2 "${FILE_NAME}" > "tmp.txt"
#   mv -f "tmp.txt" "${FILE_NAME}"
# }
#
# train_word_embeddings()
# {
#   INPUT_FILE="${DATA_DIR}/plain_text/avito_text.txt"
#   OUTPUT_FILE="${EMBED_DIR}/avito_fasttext_300d"
#
#   # train fasttext vectors
#   D:/Dropbox/avito/FastText/fasttext skipgram -input "${INPUT_FILE}" -output "${OUTPUT_FILE}" \
#   -minCount 1 -neg 25 -thread 7 -dim 300
#
#   # raname and remove first line of file
#   mv "${OUTPUT_FILE}.vec" "${OUTPUT_FILE}.txt"
#   rm_first_line "${OUTPUT_FILE}.txt"
# }
#
# train_word_embeddings
# ```

# %% [markdown]
# ### Impute missing embeddings

# %%
# remove header from vector file

# %%
import torch
from sklearn.preprocessing import normalize  
# import embedding_utils

# %%
embed_dir = '../input/embeddings'

# %%
local_list = [
  f'{embed_dir}/avito_fasttext_300d.txt',
]

# %%
# with open(f'{embed_dir}/avito_fasttext_300d.txt', encoding='utf-8') as token_text:
#     tmp = [next(token_text) for x in range(1)]
# print(tmp)

# %%
external_list = [
  f'{embed_dir}/cc.ru.300.txt', 
  f'{embed_dir}/wiki.ru.txt',
]

# %%
# with open(f'{embed_dir}/cc.ru.300.txt', encoding='utf-8') as token_text:
#     tmp = [next(token_text) for x in range(1)]
# print(tmp)

# %%
def get_save_name(local, external):
    def get_base_name(file_name):
        base = file_name.split('/')
        base = base[len(base)-1]
        base = re.sub('.txt', '', base)
        return base

    return f'{embed_dir}/imputed/'\
        f'{get_base_name(local)}_impute_'\
        f'{get_base_name(external)}.txt'

# %%
# parameter -neg is 5 so 25 # increase negative sampling increases accuracy toxic competition fasttext was fast

# %%
def read_embedding(file_name):
    """
    Reads into memory a numpy array of words and a
    corresponding dictionary of numpy word vectors.
    Args:
      file_name: Name of the file to read.
    Returns:
      A tuple of word array and word vector dictionary.
    """

    f = open(file_name, encoding='utf-8')
    word_vectors = {}
    split_pattern = re.compile(u' |\n')
    
#     i = 0 
    for line in f:
        split_line = re.split(split_pattern, line.strip())
        word_vectors[split_line[0]] = np.asarray(split_line[1:], dtype='float32')
#         if i > 6: break 
#         i += 1

    return word_vectors


def write_embedding(vectors, save_name):
    """
    Saves external word vector to disk.
    Args:
      save_name: Name of the file to save.
    Returns:
      None
    """  
    fwrite = open(save_name, 'w', encoding='utf-8')
    for word, vec in vectors.items():
        fwrite.write(word + ' ' + ' '.join(vec.astype(str)) + '\n')
    fwrite.close()


def impute_missing(local_vectors, external_vectors, vectorized=False, use_gpu=False, chunk_size=500):
    """
    For each missing word in the external dataset, find the most
    similar word present in both the local and external dataset.
    Args:
    vectorized: If True the missing words are updated one at a time
      in a for loop, otherwise the computationis vectorized.
      (default is True).  Ignored if use_gpu=True.
    use_gpu: If True use gpu to do the computation. (default is False)
    chunk_size: number of words to process on the gpu at once 
    (defaults is 500)
    Returns:
    Dictionary of imputed word vectors.
    """
    
    import torch
    from sklearn.preprocessing import normalize

    # find missing words
    print(local_vectors.keys())
    local_words, external_words = list(local_vectors.keys()), list(external_vectors.keys())
    shared_words = np.intersect1d(local_words, external_words)

    missing_words = np.setdiff1d(local_words, external_words)

    # create reference matrix
    reference_matrix = np.array([local_vectors[w] for w in shared_words])
    reference_matrix = normalize(reference_matrix).T # word vectors are columns - comment out

    # create lookup matrix
    lookup_matrix = np.array([local_vectors[w] for w in missing_words])
    #n p.array breaking numbers not as an array
    try:
        lookup_matrix = normalize(lookup_matrix)
    except:
        print(lookup_matrix)
    
    # perform lookup
    if use_gpu:

        # setup
        n_lookups = lookup_matrix.shape[0]
        n_chunks = n_lookups//chunk_size+1

        # convert to numpy array to torch tensors
        dtype = torch.cuda.FloatTensor  
        def np2tc(x): return torch.from_numpy(x).type(dtype)
        reference_matrix_gpu = np2tc(reference_matrix)
    
        # iterate through chunks
        for i in range(n_chunks):
            chunk_indexs = slice(chunk_size*i, min(chunk_size*(i+1), n_lookups))
            similarity = torch.mm(np2tc(lookup_matrix[chunk_indexs]), reference_matrix_gpu)
            _, similar_indexs = torch.max(similarity, 1)
            similar_words = shared_words[np.array(similar_indexs)]
            for m,s in zip(missing_words[chunk_indexs], similar_words):
                external_vectors[m] = external_vectors[s] 

    else: 

        if vectorized:
            for w in missing_words:
                similarity = np.matmul(local_vectors[w], reference_matrix)
                similar_word = shared_words[np.argmax(similarity)]
                external_vectors[w] = external_vectors[similar_word]

        else: 
            similarity = np.matmul(lookup_matrix, reference_matrix)
            similar_words = shared_words[np.argmax(similarity, axis=1)]
            for m,s in zip(missing_words, similar_words):
                external_vectors[m] = external_vectors[s]

    # keep only local words
    imputed_vectors = local_vectors
    for w in imputed_vectors:
        imputed_vectors[w] = external_vectors[w]
  
    return imputed_vectors

# %%
for local_file in local_list:
  
    # load local vectors
    local_vectors = read_embedding(local_file)

    for external_file in external_list[::-1]:

        # load external vectors
        external_vectors = read_embedding(external_file)
        print('done')
        # impute missing vectors
        imputed_vectors = impute_missing(local_vectors, external_vectors, use_gpu=True)
    
        # save imputed
        save_name = get_save_name(local_file, external_file)
        write_embedding(imputed_vectors, save_name)
